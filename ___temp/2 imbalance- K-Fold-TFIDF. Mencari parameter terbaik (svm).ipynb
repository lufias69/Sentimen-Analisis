# %%
import pandas as pd
import time
import numpy as np
import re
import pickle
import string, unicodedata
from unidecode import unidecode

# %%
a = time.time()

# %% [markdown]
# ## Load Data

# %%
#data = pd.read_excel('data/data_komentar_clean_1.xlsx', sheet_name = 'Sheet1') # data awl
#data = pd.read_excel('data/data_komentar_clean_1.xlsx', sheet_name = 'imbang') #imbang
data = pd.read_excel('data/data_komentar_clean_1.xlsx', sheet_name = 'imb_7525')
komentar = data['komentar'].tolist()
label = data['label'].tolist()
kode = data['kode'].tolist()

# %%
len(komentar)
# Out:
# 2500

# %% [markdown]
# ## Proses TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
      
tfidf = TfidfVectorizer() #membuat model tf-idf
##Membuat Matrix TF-IDF
tfidf_matrix = tfidf.fit_transform(komentar) #melakukan fit data -> seluruh data komentar
print(tfidf_matrix.shape)
X = tfidf_matrix.toarray() #merubah tipe data ke array
#X= tfidf_matrix
Y = np.array(kode) #labet tiap (komentat [spam dan bukan spam])/ 1:0
y = Y
# Out:
# (2500, 9534)

# %% [markdown]
# ## Proses Pemodelan

# %%
#Import Library
import numpy as np
from sklearn import svm
from sklearn.naive_bayes import ComplementNB

import pylab as pl
from sklearn.svm import SVC

# %% [markdown]
# # Mencari parameter terbaik

# %% [markdown]
# ## Proposes percobaan untuk masing masing parameter SVM

# %%
K = 10 #pembagian data uji dan data latih
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

kf = KFold(n_splits=K) 
C_range = np.arange(1.5,2.6,0.1)
gamma_range = np.arange(0.2,1.1, 0.1)

C_range_ = []
gamma_range_ = []
rerata_akurasi_svm = []
rerata_waktu_eksekusi = []
rerata_waktu_prediksi = []
count=0
for i in range(len(C_range)):
    for j in range(len(gamma_range)):
        C = C_range[i]
        gamma = gamma_range[j]
        akurasi_svm = []
        waktu_eksekusi = []
        waktu_prediksi = []
        cSVM = svm.SVC(kernel='rbf', gamma=gamma, C=C) #model
        for train_index, test_index in kf.split(X):
            #membagi data latih dan data uji
            X_train, X_test = X[train_index], X[test_index] #pembagian data latih
            y_train, y_test = y[train_index], y[test_index]
            
            start = time.time()
            #Melatih Model
            cSVM = cSVM.fit(X_train, y_train) #SVM
            end = time.time()
            waktu_eksekusi.append(end-start)
            
            #proses prediksi
            start = time.time()
            P_SVM = cSVM.predict(X_test)
            end = time.time()
            waktu_prediksi.append(end-start)
            
            akurasi_svm.append(accuracy_score(y_test, P_SVM))
        print("iterasi ke-", count)
        C_range_.append(C)
        gamma_range_.append(gamma)
        
        rr = sum(akurasi_svm)/len(akurasi_svm)
        rerata_akurasi_svm.append(rr)
        count+=1
        
        rerata_waktu_eksekusi.append(sum(waktu_eksekusi)/len(waktu_eksekusi))
        rerata_waktu_prediksi.append(sum(waktu_prediksi)/len(waktu_prediksi))
        
        #Menampilkan hasil 
        print("-"*30)
        print("C     : ", C)
        print("gamma : ", gamma)
        print("-"*20)
        print("Rata-rata Akurasi SVM : %0.2f" % (sum(akurasi_svm)/len(akurasi_svm)))
        print("Rata-rata Waktu eksekusi SVM: %0.2f" % (sum(waktu_eksekusi)/len(waktu_eksekusi)))
        print("Rata-rata Waktu prediksi  SVM: %0.2f" % (sum(waktu_prediksi)/len(waktu_prediksi)))
        print("="*30)
    
#proses mencari parameter dan akurasi terbaik
x = max(rerata_akurasi_svm)
#al = list(alpha_range)
index = rerata_akurasi_svm.index(x)
round(gamma_range_[index],2)
print("---------------------------")
print("gamma terbaik adalah :", round(gamma_range_[index],2))
print("    C terbaik adalah :", round(C_range_[index],2))
print("             Akurasi :", round(x, 2))

#MENYIMPAN HASIL
dict_komentar  = {"gamma":gamma_range_,"c":C_range_, "akurasi":rerata_akurasi_svm, "waktu eksekusi":rerata_waktu_eksekusi, "waktu prediksi":rerata_waktu_prediksi}
df = pd.DataFrame(dict_komentar,columns = ["gamma", 'c', "akurasi", "waktu eksekusi", "waktu prediksi"])
writer = pd.ExcelWriter('data/parameter-akurasi-svm_7525_acak.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='svm-parameter-svm')
#Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# iterasi ke- 0
# ------------------------------
# C     :  1.5
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.92
# Rata-rata Waktu eksekusi SVM: 55.89
# Rata-rata Waktu prediksi  SVM: 6.27
# ==============================
# iterasi ke- 1
# ------------------------------
# C     :  1.5
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 68.42
# Rata-rata Waktu prediksi  SVM: 6.43
# ==============================
# iterasi ke- 2
# ------------------------------
# C     :  1.5
# gamma :  0.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 76.81
# Rata-rata Waktu prediksi  SVM: 6.89
# ==============================
# iterasi ke- 3
# ------------------------------
# C     :  1.5
# gamma :  0.5000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 77.05
# Rata-rata Waktu prediksi  SVM: 7.00
# ==============================
# iterasi ke- 4
# ------------------------------
# C     :  1.5
# gamma :  0.6000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 78.64
# Rata-rata Waktu prediksi  SVM: 7.23
# ==============================
# iterasi ke- 5
# ------------------------------
# C     :  1.5
# gamma :  0.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 76.77
# Rata-rata Waktu prediksi  SVM: 7.34
# ==============================
# iterasi ke- 6
# ------------------------------
# C     :  1.5
# gamma :  0.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 74.50
# Rata-rata Waktu prediksi  SVM: 7.24
# ==============================
# iterasi ke- 7
# ------------------------------
# C     :  1.5
# gamma :  0.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 72.95
# Rata-rata Waktu prediksi  SVM: 7.26
# ==============================
# iterasi ke- 8
# ------------------------------
# C     :  1.5
# gamma :  1.0000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.92
# Rata-rata Waktu eksekusi SVM: 73.47
# Rata-rata Waktu prediksi  SVM: 7.25
# ==============================
# iterasi ke- 9
# ------------------------------
# C     :  1.6
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.92
# Rata-rata Waktu eksekusi SVM: 48.19
# Rata-rata Waktu prediksi  SVM: 5.57
# ==============================
# iterasi ke- 10
# ------------------------------
# C     :  1.6
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 65.60
# Rata-rata Waktu prediksi  SVM: 5.71
# ==============================
# iterasi ke- 11
# ------------------------------
# C     :  1.6
# gamma :  0.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 68.79
# Rata-rata Waktu prediksi  SVM: 6.06
# ==============================
# iterasi ke- 12
# ------------------------------
# C     :  1.6
# gamma :  0.5000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 77.80
# Rata-rata Waktu prediksi  SVM: 7.11
# ==============================
# iterasi ke- 13
# ------------------------------
# C     :  1.6
# gamma :  0.6000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 79.99
# Rata-rata Waktu prediksi  SVM: 7.30
# ==============================
# iterasi ke- 14
# ------------------------------
# C     :  1.6
# gamma :  0.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 79.84
# Rata-rata Waktu prediksi  SVM: 7.61
# ==============================
# iterasi ke- 15
# ------------------------------
# C     :  1.6
# gamma :  0.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 81.78
# Rata-rata Waktu prediksi  SVM: 7.83
# ==============================
# iterasi ke- 16
# ------------------------------
# C     :  1.6
# gamma :  0.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 83.54
# Rata-rata Waktu prediksi  SVM: 8.10
# ==============================
# iterasi ke- 17
# ------------------------------
# C     :  1.6
# gamma :  1.0000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.92
# Rata-rata Waktu eksekusi SVM: 85.10
# Rata-rata Waktu prediksi  SVM: 8.31
# ==============================
# iterasi ke- 18
# ------------------------------
# C     :  1.7000000000000002
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.92
# Rata-rata Waktu eksekusi SVM: 54.66
# Rata-rata Waktu prediksi  SVM: 6.07
# ==============================
# iterasi ke- 19
# ------------------------------
# C     :  1.7000000000000002
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 72.32
# Rata-rata Waktu prediksi  SVM: 6.30
# ==============================
# iterasi ke- 20
# ------------------------------
# C     :  1.7000000000000002
# gamma :  0.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 76.35
# Rata-rata Waktu prediksi  SVM: 6.70
# ==============================
# iterasi ke- 21
# ------------------------------
# C     :  1.7000000000000002
# gamma :  0.5000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.44
# Rata-rata Waktu prediksi  SVM: 7.02
# ==============================
# iterasi ke- 22
# ------------------------------
# C     :  1.7000000000000002
# gamma :  0.6000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.46
# Rata-rata Waktu prediksi  SVM: 7.28
# ==============================
# iterasi ke- 23
# ------------------------------
# C     :  1.7000000000000002
# gamma :  0.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 80.34
# Rata-rata Waktu prediksi  SVM: 7.64
# ==============================
# iterasi ke- 24
# ------------------------------
# C     :  1.7000000000000002
# gamma :  0.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 83.14
# Rata-rata Waktu prediksi  SVM: 7.89
# ==============================
# iterasi ke- 25
# ------------------------------
# C     :  1.7000000000000002
# gamma :  0.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 84.35
# Rata-rata Waktu prediksi  SVM: 8.26
# ==============================
# iterasi ke- 26
# ------------------------------
# C     :  1.7000000000000002
# gamma :  1.0000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 84.80
# Rata-rata Waktu prediksi  SVM: 8.29
# ==============================
# iterasi ke- 27
# ------------------------------
# C     :  1.8000000000000003
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.92
# Rata-rata Waktu eksekusi SVM: 55.99
# Rata-rata Waktu prediksi  SVM: 6.28
# ==============================
# iterasi ke- 28
# ------------------------------
# C     :  1.8000000000000003
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 76.33
# Rata-rata Waktu prediksi  SVM: 6.45
# ==============================
# iterasi ke- 29
# ------------------------------
# C     :  1.8000000000000003
# gamma :  0.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 76.35
# Rata-rata Waktu prediksi  SVM: 6.69
# ==============================
# iterasi ke- 30
# ------------------------------
# C     :  1.8000000000000003
# gamma :  0.5000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.39
# Rata-rata Waktu prediksi  SVM: 6.97
# ==============================
# iterasi ke- 31
# ------------------------------
# C     :  1.8000000000000003
# gamma :  0.6000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.57
# Rata-rata Waktu prediksi  SVM: 7.48
# ==============================
# iterasi ke- 32
# ------------------------------
# C     :  1.8000000000000003
# gamma :  0.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 80.11
# Rata-rata Waktu prediksi  SVM: 7.58
# ==============================
# iterasi ke- 33
# ------------------------------
# C     :  1.8000000000000003
# gamma :  0.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 82.03
# Rata-rata Waktu prediksi  SVM: 7.94
# ==============================
# iterasi ke- 34
# ------------------------------
# C     :  1.8000000000000003
# gamma :  0.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 83.86
# Rata-rata Waktu prediksi  SVM: 8.08
# ==============================
# iterasi ke- 35
# ------------------------------
# C     :  1.8000000000000003
# gamma :  1.0000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 83.38
# Rata-rata Waktu prediksi  SVM: 8.15
# ==============================
# iterasi ke- 36
# ------------------------------
# C     :  1.9000000000000004
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 53.20
# Rata-rata Waktu prediksi  SVM: 5.96
# ==============================
# iterasi ke- 37
# ------------------------------
# C     :  1.9000000000000004
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 72.29
# Rata-rata Waktu prediksi  SVM: 6.22
# ==============================
# iterasi ke- 38
# ------------------------------
# C     :  1.9000000000000004
# gamma :  0.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 75.30
# Rata-rata Waktu prediksi  SVM: 6.61
# ==============================
# iterasi ke- 39
# ------------------------------
# C     :  1.9000000000000004
# gamma :  0.5000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.34
# Rata-rata Waktu prediksi  SVM: 7.07
# ==============================
# iterasi ke- 40
# ------------------------------
# C     :  1.9000000000000004
# gamma :  0.6000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 79.40
# Rata-rata Waktu prediksi  SVM: 7.36
# ==============================
# iterasi ke- 41
# ------------------------------
# C     :  1.9000000000000004
# gamma :  0.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 81.28
# Rata-rata Waktu prediksi  SVM: 7.65
# ==============================
# iterasi ke- 42
# ------------------------------
# C     :  1.9000000000000004
# gamma :  0.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 82.62
# Rata-rata Waktu prediksi  SVM: 7.88
# ==============================
# iterasi ke- 43
# ------------------------------
# C     :  1.9000000000000004
# gamma :  0.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 84.38
# Rata-rata Waktu prediksi  SVM: 8.10
# ==============================
# iterasi ke- 44
# ------------------------------
# C     :  1.9000000000000004
# gamma :  1.0000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 86.71
# Rata-rata Waktu prediksi  SVM: 8.45
# ==============================
# iterasi ke- 45
# ------------------------------
# C     :  2.0000000000000004
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 55.03
# Rata-rata Waktu prediksi  SVM: 6.11
# ==============================
# iterasi ke- 46
# ------------------------------
# C     :  2.0000000000000004
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 75.23
# Rata-rata Waktu prediksi  SVM: 6.48
# ==============================
# iterasi ke- 47
# ------------------------------
# C     :  2.0000000000000004
# gamma :  0.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 77.92
# Rata-rata Waktu prediksi  SVM: 6.83
# ==============================
# iterasi ke- 48
# ------------------------------
# C     :  2.0000000000000004
# gamma :  0.5000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.88
# Rata-rata Waktu prediksi  SVM: 7.17
# ==============================
# iterasi ke- 49
# ------------------------------
# C     :  2.0000000000000004
# gamma :  0.6000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 79.89
# Rata-rata Waktu prediksi  SVM: 7.45
# ==============================
# iterasi ke- 50
# ------------------------------
# C     :  2.0000000000000004
# gamma :  0.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 80.08
# Rata-rata Waktu prediksi  SVM: 7.68
# ==============================
# iterasi ke- 51
# ------------------------------
# C     :  2.0000000000000004
# gamma :  0.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 83.24
# Rata-rata Waktu prediksi  SVM: 7.91
# ==============================
# iterasi ke- 52
# ------------------------------
# C     :  2.0000000000000004
# gamma :  0.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 84.93
# Rata-rata Waktu prediksi  SVM: 8.13
# ==============================
# iterasi ke- 53
# ------------------------------
# C     :  2.0000000000000004
# gamma :  1.0000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 85.21
# Rata-rata Waktu prediksi  SVM: 8.22
# ==============================
# iterasi ke- 54
# ------------------------------
# C     :  2.1000000000000005
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 54.87
# Rata-rata Waktu prediksi  SVM: 6.17
# ==============================
# iterasi ke- 55
# ------------------------------
# C     :  2.1000000000000005
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 75.16
# Rata-rata Waktu prediksi  SVM: 6.46
# ==============================
# iterasi ke- 56
# ------------------------------
# C     :  2.1000000000000005
# gamma :  0.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 77.54
# Rata-rata Waktu prediksi  SVM: 6.77
# ==============================
# iterasi ke- 57
# ------------------------------
# C     :  2.1000000000000005
# gamma :  0.5000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.62
# Rata-rata Waktu prediksi  SVM: 7.08
# ==============================
# iterasi ke- 58
# ------------------------------
# C     :  2.1000000000000005
# gamma :  0.6000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 79.95
# Rata-rata Waktu prediksi  SVM: 7.39
# ==============================
# iterasi ke- 59
# ------------------------------
# C     :  2.1000000000000005
# gamma :  0.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 82.21
# Rata-rata Waktu prediksi  SVM: 7.71
# ==============================
# iterasi ke- 60
# ------------------------------
# C     :  2.1000000000000005
# gamma :  0.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 83.26
# Rata-rata Waktu prediksi  SVM: 7.90
# ==============================
# iterasi ke- 61
# ------------------------------
# C     :  2.1000000000000005
# gamma :  0.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 85.02
# Rata-rata Waktu prediksi  SVM: 8.12
# ==============================
# iterasi ke- 62
# ------------------------------
# C     :  2.1000000000000005
# gamma :  1.0000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 85.29
# Rata-rata Waktu prediksi  SVM: 8.41
# ==============================
# iterasi ke- 63
# ------------------------------
# C     :  2.2000000000000006
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 55.86
# Rata-rata Waktu prediksi  SVM: 6.24
# ==============================
# iterasi ke- 64
# ------------------------------
# C     :  2.2000000000000006
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 76.63
# Rata-rata Waktu prediksi  SVM: 6.54
# ==============================
# iterasi ke- 65
# ------------------------------
# C     :  2.2000000000000006
# gamma :  0.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.44
# Rata-rata Waktu prediksi  SVM: 6.87
# ==============================
# iterasi ke- 66
# ------------------------------
# C     :  2.2000000000000006
# gamma :  0.5000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 78.09
# Rata-rata Waktu prediksi  SVM: 7.12
# ==============================
# iterasi ke- 67
# ------------------------------
# C     :  2.2000000000000006
# gamma :  0.6000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 80.72
# Rata-rata Waktu prediksi  SVM: 7.37
# ==============================
# iterasi ke- 68
# ------------------------------
# C     :  2.2000000000000006
# gamma :  0.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.94
# Rata-rata Waktu eksekusi SVM: 75.21
# Rata-rata Waktu prediksi  SVM: 7.04
# ==============================
# iterasi ke- 69
# ------------------------------
# C     :  2.2000000000000006
# gamma :  0.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.93
# Rata-rata Waktu eksekusi SVM: 73.37
# Rata-rata Waktu prediksi  SVM: 7.05
# ==============================

# %% [markdown]
# # Mencari Parameter Alpha

# %%
K = 10 #pembagian data uji dan data latih
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score#, precision_score

kf = KFold(n_splits=K)

alpha_range = np.arange(0.1,2.01,0.01)

rerata_akurasi_cnb = []
rerata_waktu_eksekusi = []
rerata_waktu_prediksi = []

count=0
for i in range(len(alpha_range)): #melakukan interasi sebanyak data parameter C
    alpha = alpha_range[i]
    akurasi_cnb = []
    comNB = ComplementNB(alpha = alpha) #model
    waktu_eksekusi = []
    waktu_prediksi = []
    tic = time.perf_counter()
    for train_index, test_index in kf.split(X):
            #membagi data latih dan data uji
        X_train, X_test = X[train_index], X[test_index] #pembagian data latih
        y_train, y_test = y[train_index], y[test_index]
    
        #Melatih Model 
        mCNB = comNB.fit(X_train, y_train) 
            
        #proses prediksi
        P_CNB = mCNB.predict(X_test)
        
        
        start = time.time()
        #Melatih Model
        mCNB = comNB.fit(X_train, y_train)  #SVM
        end = time.time()
        waktu_eksekusi.append(end-start)
            
        #proses prediksi
        start = time.time()
        P_CNB = mCNB.predict(X_test)
        end = time.time()
        waktu_prediksi.append(end-start)
        
        
        akurasi_cnb.append(accuracy_score(y_test, P_CNB))
    toc = time.perf_counter()
    print("iterasi ke-", count)    
    rr = sum(akurasi_cnb)/len(akurasi_cnb)
    rerata_akurasi_cnb.append(rr)
    
    rerata_waktu_eksekusi.append(sum(waktu_eksekusi)/len(waktu_eksekusi))
    rerata_waktu_prediksi.append(sum(waktu_prediksi)/len(waktu_prediksi))
    count+=1
    #Menampilkan hasil akhir
    print("---------------------------------")
    print("alpha : ", alpha)
    print("----------------------------")
    print("Rata-rata Akurasi cnb: %0.2f" % (sum(akurasi_cnb)/len(akurasi_cnb)))
    print("---------------------------------", toc-tic, "second")
    
#proses mencari parameter dan akurasi terbaik
x = max(rerata_akurasi_cnb)
index = rerata_akurasi_cnb.index(x)
print("---------------------------")
print("alpha terbaik adalah :", round(alpha_range[index],2))
print("             Akurasi :", round(x, 2))

round_akurasi_cnb = []
for i in rerata_akurasi_cnb:
    round_akurasi_cnb.append(round(i,2))
dict_komentar  = {"alpha":alpha_range,"akurasi":rerata_akurasi_cnb, "Akurasi round":round_akurasi_cnb, "waktu eksekusi":rerata_waktu_eksekusi, "waktu prediksi":rerata_waktu_prediksi}
df = pd.DataFrame(dict_komentar,columns = ["alpha","akurasi","Akurasi round", "waktu eksekusi", "waktu prediksi"])
writer = pd.ExcelWriter('data/parameter-akurasi-cnb_7525_time_imbalance.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='cnb-parameter-cnb')

#menyimpan file
writer.save()
# Out:
# iterasi ke- 0
# ---------------------------------
# alpha :  0.1
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.308312900000601 second
# iterasi ke- 1
# ---------------------------------
# alpha :  0.11
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.165854999999283 second
# iterasi ke- 2
# ---------------------------------
# alpha :  0.12
# ----------------------------
# Rata-rata Akurasi cnb: 0.91
# --------------------------------- 4.239653599997837 second
# iterasi ke- 3
# ---------------------------------
# alpha :  0.13
# ----------------------------
# Rata-rata Akurasi cnb: 0.91
# --------------------------------- 4.325802200000908 second
# iterasi ke- 4
# ---------------------------------
# alpha :  0.13999999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.91
# --------------------------------- 4.437700800001039 second
# iterasi ke- 5
# ---------------------------------
# alpha :  0.14999999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.39537620000192 second
# iterasi ke- 6
# ---------------------------------
# alpha :  0.15999999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.215971300000092 second
# iterasi ke- 7
# ---------------------------------
# alpha :  0.16999999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.281235100002959 second
# iterasi ke- 8
# ---------------------------------
# alpha :  0.17999999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.210367799998494 second
# iterasi ke- 9
# ---------------------------------
# alpha :  0.18999999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.092754099998274 second
# iterasi ke- 10
# ---------------------------------
# alpha :  0.19999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.136984900000243 second
# iterasi ke- 11
# ---------------------------------
# alpha :  0.20999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.095465999998851 second
# iterasi ke- 12
# ---------------------------------
# alpha :  0.21999999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.118741300000693 second
# iterasi ke- 13
# ---------------------------------
# alpha :  0.22999999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.099302999999054 second
# iterasi ke- 14
# ---------------------------------
# alpha :  0.23999999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.241638399998919 second
# iterasi ke- 15
# ---------------------------------
# alpha :  0.24999999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.188539200000378 second
# iterasi ke- 16
# ---------------------------------
# alpha :  0.2599999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.432460100000753 second
# iterasi ke- 17
# ---------------------------------
# alpha :  0.2699999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.570241599998553 second
# iterasi ke- 18
# ---------------------------------
# alpha :  0.2799999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.66817169999922 second
# iterasi ke- 19
# ---------------------------------
# alpha :  0.2899999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.677852600001643 second
# iterasi ke- 20
# ---------------------------------
# alpha :  0.29999999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.87199099999998 second
# iterasi ke- 21
# ---------------------------------
# alpha :  0.30999999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.58265940000274 second
# iterasi ke- 22
# ---------------------------------
# alpha :  0.3199999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 4.558880100001261 second
# iterasi ke- 23
# ---------------------------------
# alpha :  0.32999999999999985
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.54161380000005 second
# iterasi ke- 24
# ---------------------------------
# alpha :  0.33999999999999986
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.717600500000117 second
# iterasi ke- 25
# ---------------------------------
# alpha :  0.34999999999999987
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.612918200000422 second
# iterasi ke- 26
# ---------------------------------
# alpha :  0.3599999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.522242099999858 second
# iterasi ke- 27
# ---------------------------------
# alpha :  0.3699999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.686977400000615 second
# iterasi ke- 28
# ---------------------------------
# alpha :  0.3799999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.4916054000023 second
# iterasi ke- 29
# ---------------------------------
# alpha :  0.3899999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.747755100001086 second
# iterasi ke- 30
# ---------------------------------
# alpha :  0.3999999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.701892600001884 second
# iterasi ke- 31
# ---------------------------------
# alpha :  0.4099999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.680525299998408 second
# iterasi ke- 32
# ---------------------------------
# alpha :  0.4199999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.6546028000011574 second
# iterasi ke- 33
# ---------------------------------
# alpha :  0.4299999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.659767599998304 second
# iterasi ke- 34
# ---------------------------------
# alpha :  0.43999999999999984
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.736247100001492 second
# iterasi ke- 35
# ---------------------------------
# alpha :  0.44999999999999984
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.549455100001069 second
# iterasi ke- 36
# ---------------------------------
# alpha :  0.45999999999999985
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.5735270000004675 second
# iterasi ke- 37
# ---------------------------------
# alpha :  0.46999999999999986
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.657201300000452 second
# iterasi ke- 38
# ---------------------------------
# alpha :  0.47999999999999976
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.587416900001699 second
# iterasi ke- 39
# ---------------------------------
# alpha :  0.48999999999999977
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.529812900000252 second
# iterasi ke- 40
# ---------------------------------
# alpha :  0.4999999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.58108269999866 second
# iterasi ke- 41
# ---------------------------------
# alpha :  0.5099999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.496309199999814 second
# iterasi ke- 42
# ---------------------------------
# alpha :  0.5199999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.655176800002664 second
# iterasi ke- 43
# ---------------------------------
# alpha :  0.5299999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.599445199997717 second
# iterasi ke- 44
# ---------------------------------
# alpha :  0.5399999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.502386300002399 second
# iterasi ke- 45
# ---------------------------------
# alpha :  0.5499999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.634907800002111 second
# iterasi ke- 46
# ---------------------------------
# alpha :  0.5599999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.787990600001649 second
# iterasi ke- 47
# ---------------------------------
# alpha :  0.5699999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.616683100000955 second
# iterasi ke- 48
# ---------------------------------
# alpha :  0.5799999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.790763000000879 second
# iterasi ke- 49
# ---------------------------------
# alpha :  0.5899999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.61155250000229 second
# iterasi ke- 50
# ---------------------------------
# alpha :  0.5999999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.610575200000312 second
# iterasi ke- 51
# ---------------------------------
# alpha :  0.6099999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.613963499999954 second
# iterasi ke- 52
# ---------------------------------
# alpha :  0.6199999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.608622700001433 second
# iterasi ke- 53
# ---------------------------------
# alpha :  0.6299999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.537374999999884 second
# iterasi ke- 54
# ---------------------------------
# alpha :  0.6399999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.514111100001173 second
# iterasi ke- 55
# ---------------------------------
# alpha :  0.6499999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.5793094000000565 second
# iterasi ke- 56
# ---------------------------------
# alpha :  0.6599999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.556450200001564 second
# iterasi ke- 57
# ---------------------------------
# alpha :  0.6699999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.556752200001938 second
# iterasi ke- 58
# ---------------------------------
# alpha :  0.6799999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.661700399999972 second
# iterasi ke- 59
# ---------------------------------
# alpha :  0.6899999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.611578899999586 second
# iterasi ke- 60
# ---------------------------------
# alpha :  0.6999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.542407799999637 second
# iterasi ke- 61
# ---------------------------------
# alpha :  0.7099999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.594345599998633 second
# iterasi ke- 62
# ---------------------------------
# alpha :  0.7199999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.53905339999983 second
# iterasi ke- 63
# ---------------------------------
# alpha :  0.7299999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.5643615999979374 second
# iterasi ke- 64
# ---------------------------------
# alpha :  0.7399999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.543818099999044 second
# iterasi ke- 65
# ---------------------------------
# alpha :  0.7499999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.557070800001384 second
# iterasi ke- 66
# ---------------------------------
# alpha :  0.7599999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.734683899998345 second
# iterasi ke- 67
# ---------------------------------
# alpha :  0.7699999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.592634900000121 second
# iterasi ke- 68
# ---------------------------------
# alpha :  0.7799999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.574191899999278 second
# iterasi ke- 69
# ---------------------------------
# alpha :  0.7899999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.477901299997029 second
# iterasi ke- 70
# ---------------------------------
# alpha :  0.7999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.42260510000051 second
# iterasi ke- 71
# ---------------------------------
# alpha :  0.8099999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.502814899999066 second
# iterasi ke- 72
# ---------------------------------
# alpha :  0.8199999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.546386699999857 second
# iterasi ke- 73
# ---------------------------------
# alpha :  0.8299999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.716632200001186 second
# iterasi ke- 74
# ---------------------------------
# alpha :  0.8399999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.538049699996918 second
# iterasi ke- 75
# ---------------------------------
# alpha :  0.8499999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.596348200000648 second
# iterasi ke- 76
# ---------------------------------
# alpha :  0.8599999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.552637200002209 second
# iterasi ke- 77
# ---------------------------------
# alpha :  0.8699999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.546669699997437 second
# iterasi ke- 78
# ---------------------------------
# alpha :  0.8799999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.539586099999724 second
# iterasi ke- 79
# ---------------------------------
# alpha :  0.8899999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.565169400000741 second
# iterasi ke- 80
# ---------------------------------
# alpha :  0.8999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.637275400000362 second
# iterasi ke- 81
# ---------------------------------
# alpha :  0.9099999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.536248800002795 second
# iterasi ke- 82
# ---------------------------------
# alpha :  0.9199999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.540920199997345 second
# iterasi ke- 83
# ---------------------------------
# alpha :  0.9299999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.542886399998679 second
# iterasi ke- 84
# ---------------------------------
# alpha :  0.9399999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.448961300000519 second
# iterasi ke- 85
# ---------------------------------
# alpha :  0.9499999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.412409299999126 second
# iterasi ke- 86
# ---------------------------------
# alpha :  0.9599999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.426922899998317 second
# iterasi ke- 87
# ---------------------------------
# alpha :  0.9699999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.390488900000491 second
# iterasi ke- 88
# ---------------------------------
# alpha :  0.9799999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.411638000001403 second
# iterasi ke- 89
# ---------------------------------
# alpha :  0.9899999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.411798799999815 second
# iterasi ke- 90
# ---------------------------------
# alpha :  0.9999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.380354500000976 second
# iterasi ke- 91
# ---------------------------------
# alpha :  1.0099999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.439522200002102 second
# iterasi ke- 92
# ---------------------------------
# alpha :  1.0199999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.529468199998519 second
# iterasi ke- 93
# ---------------------------------
# alpha :  1.0299999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.533202499998879 second
# iterasi ke- 94
# ---------------------------------
# alpha :  1.0399999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.5135062000008475 second
# iterasi ke- 95
# ---------------------------------
# alpha :  1.0499999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.594598699997732 second
# iterasi ke- 96
# ---------------------------------
# alpha :  1.0599999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.547080799999094 second
# iterasi ke- 97
# ---------------------------------
# alpha :  1.0699999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.646077600002172 second
# iterasi ke- 98
# ---------------------------------
# alpha :  1.0799999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.645645799999329 second
# iterasi ke- 99
# ---------------------------------
# alpha :  1.0899999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.691565299999638 second
# iterasi ke- 100
# ---------------------------------
# alpha :  1.0999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.795037100000627 second
# iterasi ke- 101
# ---------------------------------
# alpha :  1.1099999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.630151999997906 second
# iterasi ke- 102
# ---------------------------------
# alpha :  1.1199999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.540381200000411 second
# iterasi ke- 103
# ---------------------------------
# alpha :  1.1299999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.519750499999645 second
# iterasi ke- 104
# ---------------------------------
# alpha :  1.1399999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.64033130000098 second
# iterasi ke- 105
# ---------------------------------
# alpha :  1.1499999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.58082640000066 second
# iterasi ke- 106
# ---------------------------------
# alpha :  1.1599999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.610937900000863 second
# iterasi ke- 107
# ---------------------------------
# alpha :  1.1699999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.60558680000031 second
# iterasi ke- 108
# ---------------------------------
# alpha :  1.1799999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.504185300000245 second
# iterasi ke- 109
# ---------------------------------
# alpha :  1.1899999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.606656600000861 second
# iterasi ke- 110
# ---------------------------------
# alpha :  1.1999999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.466098500000953 second
# iterasi ke- 111
# ---------------------------------
# alpha :  1.2099999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.470790600000328 second
# iterasi ke- 112
# ---------------------------------
# alpha :  1.2199999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.393853199999285 second
# iterasi ke- 113
# ---------------------------------
# alpha :  1.2299999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.495363899997756 second
# iterasi ke- 114
# ---------------------------------
# alpha :  1.2399999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.447088500000973 second
# iterasi ke- 115
# ---------------------------------
# alpha :  1.2499999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.412427900002513 second
# iterasi ke- 116
# ---------------------------------
# alpha :  1.2599999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.4191113999986555 second
# iterasi ke- 117
# ---------------------------------
# alpha :  1.2699999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.513438800000586 second
# iterasi ke- 118
# ---------------------------------
# alpha :  1.2799999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.619997199999489 second
# iterasi ke- 119
# ---------------------------------
# alpha :  1.2899999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.566822900000261 second
# iterasi ke- 120
# ---------------------------------
# alpha :  1.2999999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.583665200003452 second
# iterasi ke- 121
# ---------------------------------
# alpha :  1.3099999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.518205299998954 second
# iterasi ke- 122
# ---------------------------------
# alpha :  1.3199999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.50727790000019 second
# iterasi ke- 123
# ---------------------------------
# alpha :  1.3299999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.509878900000331 second
# iterasi ke- 124
# ---------------------------------
# alpha :  1.3399999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.668536299999687 second
# iterasi ke- 125
# ---------------------------------
# alpha :  1.3499999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.71565389999887 second
# iterasi ke- 126
# ---------------------------------
# alpha :  1.3599999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.669790399999329 second
# iterasi ke- 127
# ---------------------------------
# alpha :  1.3699999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.566602999999304 second
# iterasi ke- 128
# ---------------------------------
# alpha :  1.3799999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.595852999998897 second
# iterasi ke- 129
# ---------------------------------
# alpha :  1.3899999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.686051000000589 second
# iterasi ke- 130
# ---------------------------------
# alpha :  1.3999999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.703117299999576 second
# iterasi ke- 131
# ---------------------------------
# alpha :  1.4099999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.661218599998392 second
# iterasi ke- 132
# ---------------------------------
# alpha :  1.4199999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.516482499999256 second
# iterasi ke- 133
# ---------------------------------
# alpha :  1.4299999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.587878800000908 second
# iterasi ke- 134
# ---------------------------------
# alpha :  1.4399999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.762504499998613 second
# iterasi ke- 135
# ---------------------------------
# alpha :  1.4499999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.543124100000568 second
# iterasi ke- 136
# ---------------------------------
# alpha :  1.4599999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.7274064000012 second
# iterasi ke- 137
# ---------------------------------
# alpha :  1.4699999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.567669399999431 second
# iterasi ke- 138
# ---------------------------------
# alpha :  1.4799999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.6054942999980995 second
# iterasi ke- 139
# ---------------------------------
# alpha :  1.4899999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.580592099999194 second
# iterasi ke- 140
# ---------------------------------
# alpha :  1.4999999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.656811799999559 second
# iterasi ke- 141
# ---------------------------------
# alpha :  1.5099999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.867041600002267 second
# iterasi ke- 142
# ---------------------------------
# alpha :  1.5199999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 5.197464900000341 second
# iterasi ke- 143
# ---------------------------------
# alpha :  1.5299999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.7169404000014765 second
# iterasi ke- 144
# ---------------------------------
# alpha :  1.5399999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.644432499997492 second
# iterasi ke- 145
# ---------------------------------
# alpha :  1.5499999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.656274699998903 second
# iterasi ke- 146
# ---------------------------------
# alpha :  1.5599999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.532859099999769 second
# iterasi ke- 147
# ---------------------------------
# alpha :  1.5699999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.503427899999224 second
# iterasi ke- 148
# ---------------------------------
# alpha :  1.5799999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.675406300000759 second
# iterasi ke- 149
# ---------------------------------
# alpha :  1.5899999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.606736400000955 second
# iterasi ke- 150
# ---------------------------------
# alpha :  1.5999999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.5766333999999915 second
# iterasi ke- 151
# ---------------------------------
# alpha :  1.6099999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.778061000000889 second
# iterasi ke- 152
# ---------------------------------
# alpha :  1.6199999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.68676620000042 second
# iterasi ke- 153
# ---------------------------------
# alpha :  1.6299999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.540577100000519 second
# iterasi ke- 154
# ---------------------------------
# alpha :  1.6399999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.512790600001608 second
# iterasi ke- 155
# ---------------------------------
# alpha :  1.6499999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.503830600002402 second
# iterasi ke- 156
# ---------------------------------
# alpha :  1.6599999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.858534700000746 second
# iterasi ke- 157
# ---------------------------------
# alpha :  1.6699999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.629945500000758 second
# iterasi ke- 158
# ---------------------------------
# alpha :  1.6799999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 5.174899500001629 second
# iterasi ke- 159
# ---------------------------------
# alpha :  1.6899999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.924957600000198 second
# iterasi ke- 160
# ---------------------------------
# alpha :  1.6999999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.788162000000739 second
# iterasi ke- 161
# ---------------------------------
# alpha :  1.7099999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.675906899999973 second
# iterasi ke- 162
# ---------------------------------
# alpha :  1.7199999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.645260599998437 second
# iterasi ke- 163
# ---------------------------------
# alpha :  1.7299999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.449725000002218 second
# iterasi ke- 164
# ---------------------------------
# alpha :  1.7399999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.56033749999915 second
# iterasi ke- 165
# ---------------------------------
# alpha :  1.7499999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.962343499999406 second
# iterasi ke- 166
# ---------------------------------
# alpha :  1.7599999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.500551999997697 second
# iterasi ke- 167
# ---------------------------------
# alpha :  1.7699999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.469611600001372 second
# iterasi ke- 168
# ---------------------------------
# alpha :  1.7799999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.480408100000204 second
# iterasi ke- 169
# ---------------------------------
# alpha :  1.7899999999999991
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.482894400000077 second
# iterasi ke- 170
# ---------------------------------
# alpha :  1.7999999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.397238100002141 second
# iterasi ke- 171
# ---------------------------------
# alpha :  1.8099999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.592729200001486 second
# iterasi ke- 172
# ---------------------------------
# alpha :  1.8199999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.65386849999777 second
# iterasi ke- 173
# ---------------------------------
# alpha :  1.8299999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.020950099999027 second
# iterasi ke- 174
# ---------------------------------
# alpha :  1.8399999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.779808700001013 second
# iterasi ke- 175
# ---------------------------------
# alpha :  1.8499999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.692724799999269 second
# iterasi ke- 176
# ---------------------------------
# alpha :  1.8599999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.82476090000273 second
# iterasi ke- 177
# ---------------------------------
# alpha :  1.8699999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.848526599998877 second
# iterasi ke- 178
# ---------------------------------
# alpha :  1.8799999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.965276099999755 second
# iterasi ke- 179
# ---------------------------------
# alpha :  1.8899999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 5.154619599998114 second
# iterasi ke- 180
# ---------------------------------
# alpha :  1.8999999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.633639299998322 second
# iterasi ke- 181
# ---------------------------------
# alpha :  1.9099999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.624888500002271 second
# iterasi ke- 182
# ---------------------------------
# alpha :  1.9199999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.94
# --------------------------------- 4.861378000001423 second
# iterasi ke- 183
# ---------------------------------
# alpha :  1.9299999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.7048535000030824 second
# iterasi ke- 184
# ---------------------------------
# alpha :  1.939999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 4.980321700000786 second
# iterasi ke- 185
# ---------------------------------
# alpha :  1.949999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.283870499999466 second
# iterasi ke- 186
# ---------------------------------
# alpha :  1.959999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.14012189999994 second
# iterasi ke- 187
# ---------------------------------
# alpha :  1.969999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.32264049999867 second
# iterasi ke- 188
# ---------------------------------
# alpha :  1.979999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.054519299999811 second
# iterasi ke- 189
# ---------------------------------
# alpha :  1.989999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.112955000000511 second
# iterasi ke- 190
# ---------------------------------
# alpha :  1.9999999999999991
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.2134642000019085 second
# ---------------------------
# alpha terbaik adalah : 0.9
#              Akurasi : 0.94

# %%
len(rerata_waktu_prediksi)
# Out:
# 0
