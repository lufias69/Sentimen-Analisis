# %%
import re, string, unicodedata
import nltk
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# %%
#preprocessing

def removeStopword(str):
    stop_words = set(stopwords.words('stopword_id_artikel_islam'))
    word_tokens = word_tokenize(str)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    return ' '.join(filtered_sentence)

#remove sentence which contains only one word
def removeSentence(str): 
    word = str.split()
    wordCount = len(word)
    if(wordCount<=1):
        str = ''
    
    return str

def cleaning(str):
    #remove non-ascii
    str = unicodedata.normalize('NFKD', str).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    #remove URLs
    str = re.sub(r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))', '', str)
    #remove punctuations
    str = re.sub(r'[^\w]|_',' ',str)
    #remove digit from string
    #str = re.sub("\S*\d\S*", "", str).strip()
    #remove digit or numbers
    #str = re.sub(r"\b\d+\b", " ", str)
    #to lowercase
    str = str.lower()
    #Remove additional white spaces
    str = re.sub('[\s]+', ' ', str)
       
    return str


def preprocessing(str):
    str = removeSentence(str)
    str = cleaning(str)
    #str = removeStopword(str)
    
    return str

# %%
cleaning("SsA 1 EWQEas1cs")
# Out:
# 'ssa 1 ewqeas1cs'

# %%
import pandas as pd
import xlsxwriter

fo = pd.read_excel('data/dataset_kotor2.xlsx', sheet_name='Sheet1') #read excel file
txt = fo['komentar'].tolist()
#workbook = xlsxwriter.Workbook('clean-data.xlsx')
#worksheet = workbook.add_worksheet()

# %%
data_baru = []
asli = []

for i in txt:
    data_baru.append(preprocessing(i))
data_baru1 = []
for i in range(len(data_baru)):
    if len(data_baru[i]) > 0:
        x = data_baru[i].split()
        if len(x)>3:
            data_baru1.append(data_baru[i])
            asli.append(txt[i])

# %%
dic_komentar = {"komentar":data_baru1, "asli":asli}
df = pd.DataFrame(dic_komentar,columns = ['komentar',"asli"])
writer = pd.ExcelWriter('data/kandidat_dataset.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='Sheet1')
#df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
df
# Out:
#                                                komentar  \
# 0     akuu gkk yagggkaa agggett kakk 1iggguu ygg laa...
# 1                                    sayur kool di igku
# 2     suksesss terusss yaa kakkk ehiyaa thanks bange...
# 3                             resti p4 harganya berapa
# 4     k sggu gggg lluuuu kuuu kkk g consultant shoph...
# 5                  pengen kak cara ordernya gimana tuh
# 6     ks gtt kk rkt rukk rt ku turu 7 kg kk ks kkk t...
# 7     maantaaap banggeeet kaak eteaah akuu pakee pen...
# 8                            resti p4 order dimana yah
# 9                         mau endorsement gmn cara nya
# 10    ks gt kkk uuu sr ku kk ruuk suul r consultant ...
# 11     kkk uu trt rr l kuu u rukk ut sluru tuu gg co...
# 12       mantab bener sis saya dapat ig followers dari
# 13     rismaoktavaniiii pengen ka gimana cara ordernya
# 14    s zgggg gtttt s rtttt kuuu s turu s 1 0kg gttt...
# 15                              harganya berapa kk ayu
# ...

# %%
len(df)
# Out:
# 2973

# %%
fo = pd.read_excel('data/kandidat_dataset_label.xlsx', sheet_name='Sheet2')#read excel file
komentar = fo['komentar'].tolist()
label = fo['kode'].tolist()

k1= []
l1=[]
for i in range(len(komentar)):
    if len(komentar[i]) > 0:
        x = komentar[i].split()
        if len(x)>=7 or label[i]==1:
        #if len(x)>=5:
            k1.append(komentar[i])
            l1.append(label[i])
            
dic_komentar = {"komentar":k1, "label":l1}
df = pd.DataFrame(dic_komentar,columns = ['komentar',"label"])

writer = pd.ExcelWriter('data/kandidat_labeled.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='Sheet1')
#df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
df
# Out:
#                                                komentar  label
# 0     akuu gkk yagggkaa agggett kakk 1iggguu ygg laa...    1.0
# 1     suksesss terusss yaa kakkk ehiyaa thanks bange...    NaN
# 2     k sggu gggg lluuuu kuuu kkk g consultant shoph...    1.0
# 3     ks gtt kk rkt rukk rt ku turu 7 kg kk ks kkk t...    1.0
# 4     maantaaap banggeeet kaak eteaah akuu pakee pen...    1.0
# 5     ks gt kkk uuu sr ku kk ruuk suul r consultant ...    1.0
# 6      kkk uu trt rr l kuu u rukk ut sluru tuu gg co...    1.0
# 7        mantab bener sis saya dapat ig followers dari     1.0
# 8     s zgggg gtttt s rtttt kuuu s turu s 1 0kg gttt...    1.0
# 9      rismaoktavaniiii aku juga sama udh nyoba prod...    1.0
# 10                   mau yu brp harganya jam tgn nya yu    NaN
# 11    website bagi bagi followers dan likes instagra...    1.0
# 12     kkk uu trt rr l kuu u rukk ut sluru tuu gg he...    1.0
# 13                     cek instagram converse only 95rb    1.0
# ...

# %%
len(df)
# Out:
# 1683

# %%
data_replace  = pd.read_excel('data/Corpus_kata_replace_new.xlsx', sheet_name = 'kata_repalce')
data_hapus  = pd.read_excel('data/Corpus_kata_replace_new.xlsx', sheet_name = 'kata_hapus')
#data_olah  = pd.read_excel('data/komentar_label_new.xlsx')
#data_new = data
diganti = data_replace['kata'].tolist()
ganti = data_replace['ganti'].tolist()
hapus = data_hapus['kata'].tolist()

# %%
sp = []
for i in range(len(k1)):
    x = k1[i].split()
    for j in x:
        sp.append(j) 
setl = sorted(list(set(sp)))
#dic = {"komentar":sp}
#df = pd.DataFrame(dic,columns = ['komentar'])
len(setl)
# Out:
# 6102

# %%
#vocab = []
helper = []
for i in setl:
    for j in diganti:
        if j == i:
            helper.append(j)
for i in setl:
    for j in helper:
        if j ==

# %%
voxB  = list(set(setl) - set(helper))
print(len(setl))
print(len(voxB))

for i in diganti:
    for j in voxB:
        if i == j:
            print(i)
dic = {"kata":voxB}
df = pd.DataFrame(dic,columns = ['kata'])
writer = pd.ExcelWriter('data/list_vocab_backup.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='Sheet1')
#df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
df
# Out:
# 6102
# 5692
#                kata
# 0         ktinggaln
# 1              aman
# 2       kerudungnya
# 3            jargon
# 4        bangggettt
# 5     pemutiiiihnya
# 6            mabrur
# 7            njawab
# 8             wangi
# 9        heheheyuks
# 10              kst
# 11           padean
# 12           habesi
# 13           taibah
# 14           bridge
# 15           dooong
# 16             akyu
# 17         skincare
# 18        atttttttt
# 19            medan
# 20          arquran
# 21           yatsib
# 22         hurufnya
# 23          janjian
# 24           konser
# 25     permasalahan
# 26          syuting
# 27           karena
# 28       syailagbrn
# 29            wanna
# ...             ...
# 5662            tow
# 5663          lewat
# 5664   peninngginya
# 5665           satu
# 5666        abaikan
# 5667        berhala
# 5668           umat
# 5669      backfahmi
# 5670        sebutan
# 5671           chat
# 5672            sis
# 5673              w
# ...
