# %%
import pandas as pd
import time
import numpy as np
import re
import pickle
import string, unicodedata
from unidecode import unidecode

# %% [markdown]
# ## Load Data

# %%
data = pd.read_excel('data/data_komentar_clean_1.xlsx', sheet_name = 'Sheet1')
komentar = data['komentar'].tolist()
label = data['label'].tolist()
kode = data['kode'].tolist()

# %% [markdown]
# ## Proses TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
      
tfidf = TfidfVectorizer() #membuat model tf-idf
##Membuat Matrix TF-IDF
tfidf_matrix = tfidf.fit_transform(komentar) #melakukan fit data -> seluruh data komentar
print(tfidf_matrix.shape)
X = tfidf_matrix.toarray() #merubah tipe data ke array
#X= tfidf_matrix
Y = np.array(kode) #labet tiap (komentat [spam dan bukan spam])/ 1:0
y = Y
# Out:
# (3800, 13065)

# %% [markdown]
# ## Proses Pemodelan

# %%
#Import Library
import numpy as np
from sklearn import svm
from sklearn.naive_bayes import ComplementNB

import pylab as pl
from sklearn.svm import SVC
#from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import StratifiedKFold
#from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Mencari parameter terbaik

# %% [markdown]
# ## Proposes percobaan untuk masing masing parameter SVM

# %%
K = 10 #pembagian data uji dan data latih
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

kf = KFold(n_splits=K) 
C_range = np.arange(1,1.9,0.1)
gamma_range = np.arange(0.1,1, 0.1)

C_range_ = []
gamma_range_ = []
rerata_akurasi_svm = []
count=0
for i in range(len(C_range)):
    for j in range(len(gamma_range)):
        C = C_range[i]
        gamma = gamma_range[j]
        akurasi_svm = []
        cSVM = svm.SVC(kernel='rbf', gamma=gamma, C=C) #model
        for train_index, test_index in kf.split(X):
            #membagi data latih dan data uji
            X_train, X_test = X[train_index], X[test_index] #pembagian data latih
            y_train, y_test = y[train_index], y[test_index]
    
            #Melatih Model 
            cSVM = cSVM.fit(X_train, y_train) #SVM
            
            #proses prediksi
            P_SVM = cSVM.predict(X_test)
            akurasi_svm.append(accuracy_score(y_test, P_SVM))
        print("iterasi ke-", count)
        C_range_.append(C)
        gamma_range_.append(gamma)
        
        rr = sum(akurasi_svm)/len(akurasi_svm)
        rerata_akurasi_svm.append(rr)
        count+=1
        #Menampilkan hasil 
        print("-"*30)
        print("C     : ", C)
        print("gamma : ", gamma)
        print("-"*20)
        print("Rata-rata Akurasi SVM: %0.2f" % (sum(akurasi_svm)/len(akurasi_svm)))
        print("="*30)
    
#proses mencari parameter dan akurasi terbaik
x = max(rerata_akurasi_svm)
#al = list(alpha_range)
index = rerata_akurasi_svm.index(x)
round(gamma_range_[index],2)
print("---------------------------")
print("gamma terbaik adalah :", round(gamma_range_[index],2))
print("    C terbaik adalah :", round(C_range_[index],2))
print("             Akurasi :", round(x, 2))
# Out:
# iterasi ke- 0
# ---------------------------------
# C     :  1.0
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.88
# ---------------------------------
# iterasi ke- 1
# ---------------------------------
# C     :  1.0
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.90
# ---------------------------------
# iterasi ke- 2
# ---------------------------------
# C     :  1.0
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 3
# ---------------------------------
# C     :  1.0
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 4
# ---------------------------------
# C     :  1.0
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 5
# ---------------------------------
# C     :  1.0
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 6
# ---------------------------------
# C     :  1.0
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 7
# ---------------------------------
# C     :  1.0
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 8
# ---------------------------------
# C     :  1.0
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 9
# ---------------------------------
# C     :  1.1
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.88
# ---------------------------------
# iterasi ke- 10
# ---------------------------------
# C     :  1.1
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.90
# ---------------------------------
# iterasi ke- 11
# ---------------------------------
# C     :  1.1
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 12
# ---------------------------------
# C     :  1.1
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 13
# ---------------------------------
# C     :  1.1
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 14
# ---------------------------------
# C     :  1.1
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 15
# ---------------------------------
# C     :  1.1
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 16
# ---------------------------------
# C     :  1.1
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 17
# ---------------------------------
# C     :  1.1
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 18
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.89
# ---------------------------------
# iterasi ke- 19
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 20
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 21
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 22
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 23
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 24
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 25
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 26
# ---------------------------------
# C     :  1.2000000000000002
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 27
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.89
# ---------------------------------
# iterasi ke- 28
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 29
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 30
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 31
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 32
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 33
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 34
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 35
# ---------------------------------
# C     :  1.3000000000000003
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 36
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.89
# ---------------------------------
# iterasi ke- 37
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 38
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 39
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 40
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 41
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 42
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 43
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 44
# ---------------------------------
# C     :  1.4000000000000004
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 45
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.90
# ---------------------------------
# iterasi ke- 46
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.91
# ---------------------------------
# iterasi ke- 47
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 48
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 49
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 50
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 51
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 52
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 53
# ---------------------------------
# C     :  1.5000000000000004
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 54
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.90
# ---------------------------------
# iterasi ke- 55
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 56
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 57
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 58
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 59
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 60
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 61
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 62
# ---------------------------------
# C     :  1.6000000000000005
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 63
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.90
# ---------------------------------
# iterasi ke- 64
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 65
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 66
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 67
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.93
# ---------------------------------
# iterasi ke- 68
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.93
# ---------------------------------
# iterasi ke- 69
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.93
# ---------------------------------
# iterasi ke- 70
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 71
# ---------------------------------
# C     :  1.7000000000000006
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 72
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.1
# ----------------------------
# Rata-rata Akurasi SVM: 0.90
# ---------------------------------
# iterasi ke- 73
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.2
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 74
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.30000000000000004
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# iterasi ke- 75
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.4
# ----------------------------
# Rata-rata Akurasi SVM: 0.93
# ---------------------------------
# iterasi ke- 76
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.5
# ----------------------------
# Rata-rata Akurasi SVM: 0.93
# ---------------------------------
# iterasi ke- 77
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.6
# ----------------------------
# Rata-rata Akurasi SVM: 0.93
# ---------------------------------
# iterasi ke- 78
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.7000000000000001
# ----------------------------
# Rata-rata Akurasi SVM: 0.93
# ---------------------------------
# iterasi ke- 79
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.8
# ----------------------------
# Rata-rata Akurasi SVM: 0.93
# ---------------------------------
# iterasi ke- 80
# ---------------------------------
# C     :  1.8000000000000007
# gamma :  0.9
# ----------------------------
# Rata-rata Akurasi SVM: 0.92
# ---------------------------------
# ---------------------------
# gamma terbaik adalah : 0.5
#     C terbaik adalah : 1.8
#              Akurasi : 0.93

# %% [markdown]
# ## Menyimpan hasil percobaan SVM

# %%
#MENYIMPAN HASIL
dict_komentar  = {"gamma":gamma_range_,"c":C_range_, "akurasi":rerata_akurasi_svm}
df = pd.DataFrame(dict_komentar,columns = ["gamma", 'c', "akurasi"])
writer = pd.ExcelWriter('data/parameter-akurasi-svm.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='svm-parameter-svm')
#df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # Mencari Parameter Alpha

# %%
K = 10 #pembagian data uji dan data latih
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score#, precision_score

kf = KFold(n_splits=K)

alpha_range = np.arange(0.1,0.45,0.01)

rerata_akurasi_cnb = []

count=0
for i in range(len(alpha_range)): #melakukan interasi sebanyak data parameter C
    alpha = alpha_range[i]
    akurasi_cnb = []
    comNB = ComplementNB(alpha = alpha) #model
    tic = time.perf_counter()
    for train_index, test_index in kf.split(X):
            #membagi data latih dan data uji
        X_train, X_test = X[train_index], X[test_index] #pembagian data latih
        y_train, y_test = y[train_index], y[test_index]
    
        #Melatih Model 
        mCNB = comNB.fit(X_train, y_train) 
            
        #proses prediksi
        P_CNB = mCNB.predict(X_test)
        akurasi_cnb.append(accuracy_score(y_test, P_CNB))
    toc = time.perf_counter()
    print("iterasi ke-", count)    
    rr = sum(akurasi_cnb)/len(akurasi_cnb)
    rerata_akurasi_cnb.append(rr)
    count+=1
    #Menampilkan hasil akhir
    print("---------------------------------")
    print("alpha : ", alpha)
    print("----------------------------")
    print("Rata-rata Akurasi cnb: %0.2f" % (sum(akurasi_cnb)/len(akurasi_cnb)))
    print("---------------------------------", toc-tic, "second")
    
#proses mencari parameter dan akurasi terbaik
x = max(rerata_akurasi_cnb)
index = rerata_akurasi_cnb.index(x)
print("---------------------------")
print("alpha terbaik adalah :", round(alpha_range[index],2))
print("             Akurasi :", round(x, 2))
# Out:
# iterasi ke- 0
# ---------------------------------
# alpha :  0.1
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.390998599549511 second
# iterasi ke- 1
# ---------------------------------
# alpha :  0.11
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.921666950882837 second
# iterasi ke- 2
# ---------------------------------
# alpha :  0.12
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.01413256676172 second
# iterasi ke- 3
# ---------------------------------
# alpha :  0.13
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.195316753983583 second
# iterasi ke- 4
# ---------------------------------
# alpha :  0.13999999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.0497443042091845 second
# iterasi ke- 5
# ---------------------------------
# alpha :  0.14999999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.045521225022174 second
# iterasi ke- 6
# ---------------------------------
# alpha :  0.15999999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.124676964729318 second
# iterasi ke- 7
# ---------------------------------
# alpha :  0.16999999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.037998824069312 second
# iterasi ke- 8
# ---------------------------------
# alpha :  0.17999999999999997
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.110236917771104 second
# iterasi ke- 9
# ---------------------------------
# alpha :  0.18999999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.080422531780087 second
# iterasi ke- 10
# ---------------------------------
# alpha :  0.19999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.999385698022849 second
# iterasi ke- 11
# ---------------------------------
# alpha :  0.20999999999999996
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.9162564187314075 second
# iterasi ke- 12
# ---------------------------------
# alpha :  0.21999999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.917770116743711 second
# iterasi ke- 13
# ---------------------------------
# alpha :  0.22999999999999995
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.994596710422783 second
# iterasi ke- 14
# ---------------------------------
# alpha :  0.23999999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.894312735671718 second
# iterasi ke- 15
# ---------------------------------
# alpha :  0.24999999999999992
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.923125012756799 second
# iterasi ke- 16
# ---------------------------------
# alpha :  0.2599999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.9957281980409505 second
# iterasi ke- 17
# ---------------------------------
# alpha :  0.2699999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.958946455648771 second
# iterasi ke- 18
# ---------------------------------
# alpha :  0.2799999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 6.053085106172844 second
# iterasi ke- 19
# ---------------------------------
# alpha :  0.2899999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.989822866387016 second
# iterasi ke- 20
# ---------------------------------
# alpha :  0.29999999999999993
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.9435773839426815 second
# iterasi ke- 21
# ---------------------------------
# alpha :  0.30999999999999994
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.001490324250057 second
# iterasi ke- 22
# ---------------------------------
# alpha :  0.3199999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.12226419988977 second
# iterasi ke- 23
# ---------------------------------
# alpha :  0.32999999999999985
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 6.186593731749554 second
# iterasi ke- 24
# ---------------------------------
# alpha :  0.33999999999999986
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 6.14363506117013 second
# iterasi ke- 25
# ---------------------------------
# alpha :  0.34999999999999987
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 6.134545959729962 second
# iterasi ke- 26
# ---------------------------------
# alpha :  0.3599999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 6.149694462130242 second
# iterasi ke- 27
# ---------------------------------
# alpha :  0.3699999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 6.052777296768454 second
# iterasi ke- 28
# ---------------------------------
# alpha :  0.3799999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 6.193320437161788 second
# iterasi ke- 29
# ---------------------------------
# alpha :  0.3899999999999999
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 6.154704677451974 second
# iterasi ke- 30
# ---------------------------------
# alpha :  0.3999999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.9590122972326185 second
# iterasi ke- 31
# ---------------------------------
# alpha :  0.4099999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.949150874014123 second
# iterasi ke- 32
# ---------------------------------
# alpha :  0.4199999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.93
# --------------------------------- 5.848655218571025 second
# iterasi ke- 33
# ---------------------------------
# alpha :  0.4299999999999998
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 5.891666233209577 second
# iterasi ke- 34
# ---------------------------------
# alpha :  0.43999999999999984
# ----------------------------
# Rata-rata Akurasi cnb: 0.92
# --------------------------------- 6.031365284498179 second
# ---------------------------
# alpha terbaik adalah : 0.38
#              Akurasi : 0.93

# %% [markdown]
# ## Menyimpan hasil percobaan CNB

# %%
round_akurasi_cnb = []
for i in rerata_akurasi_cnb:
    round_akurasi_cnb.append(round(i,2))
dict_komentar  = {"alpha":alpha_range,"akurasi":rerata_akurasi_cnb, "Akurasi round":round_akurasi_cnb}
df = pd.DataFrame(dict_komentar,columns = ["alpha","akurasi","Akurasi round"])
writer = pd.ExcelWriter('data/parameter-akurasi-cnb.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='cnb-parameter-cnb')

#menyimpan file
writer.save()
